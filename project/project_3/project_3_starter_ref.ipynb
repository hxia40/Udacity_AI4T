# %% [markdown]
# # Project 3: Smart Beta Portfolio and Portfolio Optimization
#
# ## Overview
#
#
# Smart beta has a broad meaning, but we can say in practice that when we use the universe of stocks from an index, and then apply some weighting scheme other than market cap weighting, it can be considered a type of smart beta fund.  A Smart Beta portfolio generally gives investors exposure or "beta" to one or more types of market characteristics (or factors) that are believed to predict prices while giving investors a diversified broad exposure to a particular market. Smart Beta portfolios generally target momentum, earnings quality, low volatility, and dividends or some combination. Smart Beta Portfolios are generally rebalanced infrequently and follow relatively simple rules or algorithms that are passively managed.  Model changes to these types of funds are also rare requiring prospectus filings with US Security and Exchange Commission in the case of US focused mutual funds or ETFs.. Smart Beta portfolios are generally long-only, they do not short stocks.
#
# In contrast, a purely alpha-focused quantitative fund may use multiple models or algorithms to create a portfolio. The portfolio manager retains discretion in upgrading or changing the types of models and how often to rebalance the portfolio in attempt to maximize performance in comparison to a stock benchmark.  Managers may have discretion to short stocks in portfolios.
#
# Imagine you're a portfolio manager, and wish to try out some different portfolio weighting methods.
#
# One way to design portfolio is to look at certain accounting measures (fundamentals) that, based on past trends, indicate stocks that produce better results.
#
#
# For instance, you may start with a hypothesis that dividend-issuing stocks tend to perform better than stocks that do not. This may not always be true of all companies; for instance, Apple does not issue dividends, but has had good historical performance.  The hypothesis about dividend-paying stocks may go something like this:
#
# Companies that regularly issue dividends may also be more prudent in allocating their available cash, and may indicate that they are more conscious of prioritizing shareholder interests.  For example, a CEO may decide to reinvest cash into pet projects that produce low returns.  Or, the CEO may do some analysis, identify that reinvesting within the company produces lower returns compared to a diversified portfolio, and so decide that shareholders would be better served if they were given the cash (in the form of dividends).  So according to this hypothesis, dividends may be both a proxy for how the company is doing (in terms of earnings and cash flow), but also a signal that the company acts in the best interest of its shareholders.  Of course, it's important to test whether this works in practice.
#
#
# You may also have another hypothesis, with which you wish to design a portfolio that can then be made into an ETF.  You may find that investors may wish to invest in passive beta funds, but wish to have less risk exposure (less volatility) in their investments.  The goal of having a low volatility fund that still produces returns similar to an index may be appealing to investors who have a shorter investment time horizon, and so are more risk averse.
#
# So the objective of your proposed portfolio is to design a portfolio that closely tracks an index, while also minimizing the portfolio variance.  Also, if this portfolio can match the returns of the index with less volatility, then it has a higher risk-adjusted return (same return, lower volatility).
#
# Smart Beta ETFs can be designed with both of these two general methods (among others): alternative weighting and minimum volatility ETF.
#
#
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment. After implementing the function, run the cell to test it against the unit tests we've provided. For each problem, we provide one or more unit tests from our `project_tests` package. These unit tests won't tell you if your answer is correct, but will warn you of any major errors. Your code will be checked for the correct solution when you submit it to Udacity.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# The other packages that we're importing are `helper`, `project_helper`, and `project_tests`. These are custom packages built to help you solve the problems.  The `helper` and `project_helper` module contains utility functions and graph functions. The `project_tests` contains the unit tests for all the problems.
# ### Install Packages

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Requirement already satisfied: colour==0.1.5 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from -r requirements.txt (line 1)) (0.1.5)
# Collecting cvxpy==1.0.3
#   Using cached https://files.pythonhosted.org/packages/a1/59/2613468ffbbe3a818934d06b81b9f4877fe054afbf4f99d2f43f398a0b34/cvxpy-1.0.3.tar.gz
# Requirement already satisfied: cycler==0.10.0 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from -r requirements.txt (line 3)) (0.10.0)
# Collecting numpy==1.13.3
#   Using cached https://files.pythonhosted.org/packages/ea/df/f0671353e3d2eab4c87df014ad09505268561f6b09d0dc257d1b32653cfe/numpy-1.13.3-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Requirement already satisfied: pandas==0.21.1 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from -r requirements.txt (line 5)) (0.21.1)
# Processing /Users/huixia/Library/Caches/pip/wheels/98/54/81/dd92d5b0858fac680cd7bdb8800eb26c001dd9f5dc8b1bc0ba/plotly-2.2.3-cp27-none-any.whl
# Requirement already satisfied: pyparsing==2.2.0 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from -r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: python-dateutil==2.6.1 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from -r requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: pytz==2017.3 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from -r requirements.txt (line 9)) (2017.3)
# Requirement already satisfied: requests==2.18.4 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from -r requirements.txt (line 10)) (2.18.4)
# Collecting scipy==1.0.0
#   Using cached https://files.pythonhosted.org/packages/4d/e4/e92135b070c0913cbee59849b61f57076ac33d8a754be0fef581a28676f9/scipy-1.0.0-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# Requirement already satisfied: scikit-learn==0.19.1 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from -r requirements.txt (line 12)) (0.19.1)
# Collecting six==1.11.0
#   Using cached https://files.pythonhosted.org/packages/67/4b/141a581104b1f6397bfa78ac9d43d8ad29a7ca43ea90a2d863fe3056e86a/six-1.11.0-py2.py3-none-any.whl
# Requirement already satisfied: tqdm==4.19.5 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from -r requirements.txt (line 14)) (4.19.5)
# Requirement already satisfied: osqp in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from cvxpy==1.0.3->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: ecos>=2 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from cvxpy==1.0.3->-r requirements.txt (line 2)) (2.0.7.post1)
# Requirement already satisfied: scs>=1.1.3 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from cvxpy==1.0.3->-r requirements.txt (line 2)) (2.1.1.post2)
# Requirement already satisfied: multiprocess in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from cvxpy==1.0.3->-r requirements.txt (line 2)) (0.70.9)
# Processing /Users/huixia/Library/Caches/pip/wheels/6a/80/bf/30024738b03fa5aa521e2a2ac952a8d77d0c65e68d92bcd3b6/fastcache-1.1.0-cp27-cp27m-macosx_10_14_intel.whl
# Requirement already satisfied: toolz in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from cvxpy==1.0.3->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: nbformat>=4.2 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from plotly==2.2.3->-r requirements.txt (line 6)) (4.4.0)
# Requirement already satisfied: decorator>=4.0.6 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from plotly==2.2.3->-r requirements.txt (line 6)) (4.4.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from requests==2.18.4->-r requirements.txt (line 10)) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from requests==2.18.4->-r requirements.txt (line 10)) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from requests==2.18.4->-r requirements.txt (line 10)) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from requests==2.18.4->-r requirements.txt (line 10)) (2019.11.28)
# Requirement already satisfied: future in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from osqp->cvxpy==1.0.3->-r requirements.txt (line 2)) (0.18.2)
# Requirement already satisfied: dill>=0.3.1 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from multiprocess->cvxpy==1.0.3->-r requirements.txt (line 2)) (0.3.1.1)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (4.6.1)
# Requirement already satisfied: traitlets>=4.1 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (4.3.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (42.0.2.post20191203)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (0.15.6)
# Requirement already satisfied: functools32; python_version < "3" in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (3.2.3.post2)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (19.3.0)
# Requirement already satisfied: enum34; python_version == "2.7" in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from traitlets>=4.1->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (1.1.6)
# Requirement already satisfied: configparser>=3.5; python_version < "3" in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (4.0.2)
# Requirement already satisfied: contextlib2; python_version < "3" in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (0.6.0.post1)
# Requirement already satisfied: pathlib2; python_version < "3" in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (2.3.5)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (0.5.2)
# Requirement already satisfied: scandir; python_version < "3.5" in /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages (from pathlib2; python_version < "3"->importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 6)) (1.10.0)
# Building wheels for collected packages: cvxpy
#   Building wheel for cvxpy (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/envs/AI4T/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-install-ghpTHl/cvxpy/setup.py'"'"'; __file__='"'"'/private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-install-ghpTHl/cvxpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-wheel-Y_Gxt_ --python-tag cp27
#        cwd: /private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-install-ghpTHl/cvxpy/
#   Complete output (322 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-2.7
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy
#   copying cvxpy/error.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy
#   copying cvxpy/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy
#   copying cvxpy/settings.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/max.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/cummax.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/matrix_frac.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/lambda_max.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/sigma_max.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/total_variation.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/sum_smallest.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/norm1.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/lambda_sum_smallest.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/norm.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/pnorm.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/sum_largest.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/lambda_sum_largest.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/sum_squares.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/log_sum_exp.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/norm_nuc.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/mixed_norm.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/min.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/quad_over_lin.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/geo_mean.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/axis_atom.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/lambda_min.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/norm_inf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/quad_form.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/log_det.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/harmonic_mean.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   copying cvxpy/atoms/atom.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/vec.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/trace.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/unary_operators.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/vstack.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/affine_atom.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/index.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/upper_tri.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/binary_operators.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/hstack.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/reshape.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/bmat.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/promote.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/real.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/kron.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/imag.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/transpose.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/diag.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/add_expr.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/diff.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/sum.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/conv.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/cumsum.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   copying cvxpy/atoms/affine/conj.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/kl_div.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/pos.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/neg.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/sqrt.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/entr.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/log.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/logistic.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/elementwise.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/abs.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/maximum.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/minimum.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/huber.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/scalene.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/square.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/inv_pos.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/exp.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/log1p.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   copying cvxpy/atoms/elementwise/power.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/elementwise
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/cvxcore
#   copying cvxpy/cvxcore/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/cvxcore
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/python
#   copying cvxpy/cvxcore/python/canonInterface.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/python
#   copying cvxpy/cvxcore/python/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/python
#   copying cvxpy/cvxcore/python/cvxcore.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/python
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/constraint.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/nonlinear.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/second_order.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/exponential.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/zero.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/nonpos.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/soc_axis.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/psd.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   copying cvxpy/constraints/utilities.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/constraints
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions
#   copying cvxpy/expressions/cvxtypes.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions
#   copying cvxpy/expressions/leaf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions
#   copying cvxpy/expressions/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions
#   copying cvxpy/expressions/variable.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions
#   copying cvxpy/expressions/expression.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions/constants
#   copying cvxpy/expressions/constants/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions/constants
#   copying cvxpy/expressions/constants/callback_param.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions/constants
#   copying cvxpy/expressions/constants/constant.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions/constants
#   copying cvxpy/expressions/constants/parameter.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/expressions/constants
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface
#   copying cvxpy/interface/base_matrix_interface.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface
#   copying cvxpy/interface/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface
#   copying cvxpy/interface/scipy_wrapper.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface
#   copying cvxpy/interface/matrix_utilities.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface/numpy_interface
#   copying cvxpy/interface/numpy_interface/matrix_interface.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface/numpy_interface
#   copying cvxpy/interface/numpy_interface/sparse_matrix_interface.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface/numpy_interface
#   copying cvxpy/interface/numpy_interface/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface/numpy_interface
#   copying cvxpy/interface/numpy_interface/ndarray_interface.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/interface/numpy_interface
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/lin_ops
#   copying cvxpy/lin_ops/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/lin_ops
#   copying cvxpy/lin_ops/lin_op.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/lin_ops
#   copying cvxpy/lin_ops/lin_constraints.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/lin_ops
#   copying cvxpy/lin_ops/lin_utils.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/lin_ops
#   copying cvxpy/lin_ops/tree_mat.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/lin_ops
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems
#   copying cvxpy/problems/kktsolver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems
#   copying cvxpy/problems/objective.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems
#   copying cvxpy/problems/xpress_problem.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems
#   copying cvxpy/problems/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems
#   copying cvxpy/problems/problem.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems
#   copying cvxpy/problems/iterative.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/problem_data
#   copying cvxpy/problems/problem_data/problem_data.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/problem_data
#   copying cvxpy/problems/problem_data/sym_data.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/problem_data
#   copying cvxpy/problems/problem_data/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/problem_data
#   copying cvxpy/problems/problem_data/compr_matrix.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/problem_data
#   copying cvxpy/problems/problem_data/matrix_data.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/problem_data
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   copying cvxpy/problems/solvers/ecos_intf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   copying cvxpy/problems/solvers/glpk_mi_intf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   copying cvxpy/problems/solvers/glpk_intf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   copying cvxpy/problems/solvers/solver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   copying cvxpy/problems/solvers/gurobi_intf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   copying cvxpy/problems/solvers/xpress_intf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   copying cvxpy/problems/solvers/cbc_intf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   copying cvxpy/problems/solvers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   copying cvxpy/problems/solvers/cvxopt_intf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/problems/solvers
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/cvx_attr2constr.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/canonicalization.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/reduction.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/chain.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/solution.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/inverse_data.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/eval_params.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/matrix_stuffing.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/utilities.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   copying cvxpy/reductions/flip_objective.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real
#   copying cvxpy/reductions/complex2real/complex2real.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real
#   copying cvxpy/reductions/complex2real/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real/atom_canonicalizers
#   copying cvxpy/reductions/complex2real/atom_canonicalizers/constant_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real/atom_canonicalizers
#   copying cvxpy/reductions/complex2real/atom_canonicalizers/variable_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real/atom_canonicalizers
#   copying cvxpy/reductions/complex2real/atom_canonicalizers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real/atom_canonicalizers
#   copying cvxpy/reductions/complex2real/atom_canonicalizers/aff_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real/atom_canonicalizers
#   copying cvxpy/reductions/complex2real/atom_canonicalizers/pnorm_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real/atom_canonicalizers
#   copying cvxpy/reductions/complex2real/atom_canonicalizers/matrix_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real/atom_canonicalizers
#   copying cvxpy/reductions/complex2real/atom_canonicalizers/zero_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real/atom_canonicalizers
#   copying cvxpy/reductions/complex2real/atom_canonicalizers/abs_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/complex2real/atom_canonicalizers
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone
#   copying cvxpy/reductions/dcp2cone/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone
#   copying cvxpy/reductions/dcp2cone/cone_matrix_stuffing.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone
#   copying cvxpy/reductions/dcp2cone/dcp2cone.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/quad_form_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/log1p_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/log_det_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/geo_mean_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/exp_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/quad_over_lin_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/power_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/log_sum_exp_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/normNuc_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/logistic_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/matrix_frac_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/sigma_max_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/cumsum_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/pnorm_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/lambda_sum_largest_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/lambda_max_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/huber_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/entr_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/log_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/indicator_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   copying cvxpy/reductions/dcp2cone/atom_canonicalizers/kl_div_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl
#   copying cvxpy/reductions/eliminate_pwl/eliminate_pwl.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl
#   copying cvxpy/reductions/eliminate_pwl/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#   copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/norm1_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#   copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#   copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/max_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#   copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/maximum_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#   copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/sum_largest_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#   copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/norm_inf_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#   copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/abs_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form
#   copying cvxpy/reductions/qp2quad_form/qp_matrix_stuffing.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form
#   copying cvxpy/reductions/qp2quad_form/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form
#   copying cvxpy/reductions/qp2quad_form/qp2symbolic_qp.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#   copying cvxpy/reductions/qp2quad_form/atom_canonicalizers/quad_form_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#   copying cvxpy/reductions/qp2quad_form/atom_canonicalizers/quad_over_lin_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#   copying cvxpy/reductions/qp2quad_form/atom_canonicalizers/power_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#   copying cvxpy/reductions/qp2quad_form/atom_canonicalizers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#   copying cvxpy/reductions/solvers/solving_chain.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#   copying cvxpy/reductions/solvers/solver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#   copying cvxpy/reductions/solvers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#   copying cvxpy/reductions/solvers/defines.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#   copying cvxpy/reductions/solvers/constant_solver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#   copying cvxpy/reductions/solvers/utilities.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/ls_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/conic_solver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/ecos_bb_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/cbc_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/elemental_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/ecos_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/mosek_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/scs_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/xpress_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/cvxopt_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/glpk_mi_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/glpk_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/gurobi_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   copying cvxpy/reductions/solvers/conic_solvers/julia_opt_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#   copying cvxpy/reductions/solvers/qp_solvers/osqp_qpif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#   copying cvxpy/reductions/solvers/qp_solvers/qp_solver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#   copying cvxpy/reductions/solvers/qp_solvers/cplex_qpif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#   copying cvxpy/reductions/solvers/qp_solvers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#   copying cvxpy/reductions/solvers/qp_solvers/gurobi_qpif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/lp_solvers
#   copying cvxpy/reductions/solvers/lp_solvers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/lp_solvers
#   copying cvxpy/reductions/solvers/lp_solvers/cbc_lpif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/lp_solvers
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/base_test.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_mip_vars.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_nonlinear_atoms.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_expressions.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_constant_atoms.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_semidefinite_vars.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_shape.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_lin_ops.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_atoms.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_solvers.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_scs.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_objectives.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_convolution.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_qp.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_mosek_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_matrices.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_cbc.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_non_optimal.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_quad_form.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_constraints.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_monotonicity.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_quadratic.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_domain.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_problem.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_complex.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_linear_cone.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_interfaces.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_curvature.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_elemental.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_julia_opt.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_examples.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_sign.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   copying cvxpy/tests/test_grad.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#   copying cvxpy/transforms/indicator.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#   copying cvxpy/transforms/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#   copying cvxpy/transforms/separable_problems.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#   copying cvxpy/transforms/partial_optimize.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#   copying cvxpy/transforms/linearize.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#   copying cvxpy/transforms/scalarize.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#   creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/cvxpy_upgrade.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/replace_quad_forms.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/power_tools.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/performance_utils.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/key_utils.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/canonical.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/shape.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/sign.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/grad.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   copying cvxpy/utilities/coeff_extractor.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#   running build_ext
#   building '_cvxcore' extension
#   creating build/temp.macosx-10.7-x86_64-2.7
#   creating build/temp.macosx-10.7-x86_64-2.7/cvxpy
#   creating build/temp.macosx-10.7-x86_64-2.7/cvxpy/cvxcore
#   creating build/temp.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/src
#   creating build/temp.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/python
#   gcc -fno-strict-aliasing -I/opt/anaconda3/envs/AI4T/include -arch x86_64 -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -Icvxpy/cvxcore/src/ -Icvxpy/cvxcore/python/ -Icvxpy/cvxcore/include/Eigen -I/opt/anaconda3/envs/AI4T/lib/python2.7/site-packages/numpy/core/include -I/opt/anaconda3/envs/AI4T/include/python2.7 -c cvxpy/cvxcore/src/cvxcore.cpp -o build/temp.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/src/cvxcore.o
#   warning: include path for stdlibc++ headers not found; pass '-std=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   In file included from cvxpy/cvxcore/src/cvxcore.cpp:15:
#   cvxpy/cvxcore/src/cvxcore.hpp:18:10: fatal error: 'vector' file not found
#   #include <vector>
#            ^~~~~~~~
#   1 warning and 1 error generated.
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for cvxpy
#   Running setup.py clean for cvxpy
# Failed to build cvxpy
# Installing collected packages: fastcache, six, numpy, scipy, cvxpy, plotly
#   Found existing installation: six 1.13.0
#     Uninstalling six-1.13.0:
#       Successfully uninstalled six-1.13.0
#   Found existing installation: numpy 1.16.5
#     Uninstalling numpy-1.16.5:
#       Successfully uninstalled numpy-1.16.5
#   Found existing installation: scipy 1.2.2
#     Uninstalling scipy-1.2.2:
#       Successfully uninstalled scipy-1.2.2
#   Found existing installation: cvxpy 1.0.25
#     Uninstalling cvxpy-1.0.25:
#       Successfully uninstalled cvxpy-1.0.25
#     Running setup.py install for cvxpy ... error
#     ERROR: Command errored out with exit status 1:
#      command: /opt/anaconda3/envs/AI4T/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-install-ghpTHl/cvxpy/setup.py'"'"'; __file__='"'"'/private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-install-ghpTHl/cvxpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-record-2ro8mx/install-record.txt --single-version-externally-managed --compile
#          cwd: /private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-install-ghpTHl/cvxpy/
#     Complete output (322 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.7-x86_64-2.7
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy
#     copying cvxpy/error.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy
#     copying cvxpy/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy
#     copying cvxpy/settings.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/max.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/cummax.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/matrix_frac.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/lambda_max.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/sigma_max.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/total_variation.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/sum_smallest.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/norm1.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/lambda_sum_smallest.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/norm.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/pnorm.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/sum_largest.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/lambda_sum_largest.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/sum_squares.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/log_sum_exp.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/norm_nuc.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/mixed_norm.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/min.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/quad_over_lin.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/geo_mean.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/axis_atom.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/lambda_min.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/norm_inf.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/quad_form.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/log_det.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/harmonic_mean.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     copying cvxpy/atoms/atom.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/vec.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/trace.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/unary_operators.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/vstack.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/affine_atom.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/index.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/upper_tri.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/binary_operators.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/hstack.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/reshape.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/bmat.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/promote.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/real.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
#     copying cvxpy/atoms/affine/kron.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/atoms/affine
# ...
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/matrix_frac_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/sigma_max_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/cumsum_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/pnorm_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/lambda_sum_largest_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/lambda_max_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/huber_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/entr_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/log_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/indicator_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     copying cvxpy/reductions/dcp2cone/atom_canonicalizers/kl_div_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/dcp2cone/atom_canonicalizers
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl
#     copying cvxpy/reductions/eliminate_pwl/eliminate_pwl.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl
#     copying cvxpy/reductions/eliminate_pwl/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#     copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/norm1_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#     copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#     copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/max_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#     copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/maximum_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#     copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/sum_largest_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#     copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/norm_inf_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#     copying cvxpy/reductions/eliminate_pwl/atom_canonicalizers/abs_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/eliminate_pwl/atom_canonicalizers
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form
#     copying cvxpy/reductions/qp2quad_form/qp_matrix_stuffing.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form
#     copying cvxpy/reductions/qp2quad_form/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form
#     copying cvxpy/reductions/qp2quad_form/qp2symbolic_qp.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#     copying cvxpy/reductions/qp2quad_form/atom_canonicalizers/quad_form_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#     copying cvxpy/reductions/qp2quad_form/atom_canonicalizers/quad_over_lin_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#     copying cvxpy/reductions/qp2quad_form/atom_canonicalizers/power_canon.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#     copying cvxpy/reductions/qp2quad_form/atom_canonicalizers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/qp2quad_form/atom_canonicalizers
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#     copying cvxpy/reductions/solvers/solving_chain.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#     copying cvxpy/reductions/solvers/solver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#     copying cvxpy/reductions/solvers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#     copying cvxpy/reductions/solvers/defines.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#     copying cvxpy/reductions/solvers/constant_solver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#     copying cvxpy/reductions/solvers/utilities.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/ls_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/conic_solver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/ecos_bb_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/cbc_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/elemental_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/ecos_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/mosek_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/scs_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/xpress_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/cvxopt_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/glpk_mi_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/glpk_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/gurobi_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     copying cvxpy/reductions/solvers/conic_solvers/julia_opt_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/conic_solvers
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#     copying cvxpy/reductions/solvers/qp_solvers/osqp_qpif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#     copying cvxpy/reductions/solvers/qp_solvers/qp_solver.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#     copying cvxpy/reductions/solvers/qp_solvers/cplex_qpif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#     copying cvxpy/reductions/solvers/qp_solvers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#     copying cvxpy/reductions/solvers/qp_solvers/gurobi_qpif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/qp_solvers
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/lp_solvers
#     copying cvxpy/reductions/solvers/lp_solvers/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/lp_solvers
#     copying cvxpy/reductions/solvers/lp_solvers/cbc_lpif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/reductions/solvers/lp_solvers
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/base_test.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_mip_vars.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_nonlinear_atoms.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_expressions.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_constant_atoms.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_semidefinite_vars.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_shape.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_lin_ops.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_atoms.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_solvers.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_scs.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_objectives.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_convolution.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_qp.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_mosek_conif.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_matrices.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_cbc.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_non_optimal.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_quad_form.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_constraints.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_monotonicity.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_quadratic.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_domain.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_problem.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_complex.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_linear_cone.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_interfaces.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_curvature.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_elemental.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_julia_opt.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_examples.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_sign.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     copying cvxpy/tests/test_grad.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/tests
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#     copying cvxpy/transforms/indicator.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#     copying cvxpy/transforms/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#     copying cvxpy/transforms/separable_problems.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#     copying cvxpy/transforms/partial_optimize.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#     copying cvxpy/transforms/linearize.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#     copying cvxpy/transforms/scalarize.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/transforms
#     creating build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/cvxpy_upgrade.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/replace_quad_forms.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/power_tools.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/performance_utils.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/__init__.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/key_utils.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/canonical.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/shape.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/sign.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/grad.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     copying cvxpy/utilities/coeff_extractor.py -> build/lib.macosx-10.7-x86_64-2.7/cvxpy/utilities
#     running build_ext
#     building '_cvxcore' extension
#     creating build/temp.macosx-10.7-x86_64-2.7
#     creating build/temp.macosx-10.7-x86_64-2.7/cvxpy
#     creating build/temp.macosx-10.7-x86_64-2.7/cvxpy/cvxcore
#     creating build/temp.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/src
#     creating build/temp.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/python
#     gcc -fno-strict-aliasing -I/opt/anaconda3/envs/AI4T/include -arch x86_64 -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -Icvxpy/cvxcore/src/ -Icvxpy/cvxcore/python/ -Icvxpy/cvxcore/include/Eigen -I/opt/anaconda3/envs/AI4T/lib/python2.7/site-packages/numpy/core/include -I/opt/anaconda3/envs/AI4T/include/python2.7 -c cvxpy/cvxcore/src/cvxcore.cpp -o build/temp.macosx-10.7-x86_64-2.7/cvxpy/cvxcore/src/cvxcore.o
#     warning: include path for stdlibc++ headers not found; pass '-std=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     In file included from cvxpy/cvxcore/src/cvxcore.cpp:15:
#     cvxpy/cvxcore/src/cvxcore.hpp:18:10: fatal error: 'vector' file not found
#     #include <vector>
#              ^~~~~~~~
#     1 warning and 1 error generated.
#     error: command 'gcc' failed with exit status 1
#     ----------------------------------------
#   Rolling back uninstall of cvxpy
#   Moving to /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages/_cvxcore.so
#    from /private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-uninstall-HE2oHK/_cvxcore.so
#   Moving to /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages/cvxpy-1.0.25.dist-info/
#    from /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages/~vxpy-1.0.25.dist-info
#   Moving to /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages/cvxpy/
#    from /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages/~vxpy
# ERROR: Command errored out with exit status 1: /opt/anaconda3/envs/AI4T/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-install-ghpTHl/cvxpy/setup.py'"'"'; __file__='"'"'/private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-install-ghpTHl/cvxpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/m2/02s5_6cx2gnfg7__3r24l_ph0000gp/T/pip-record-2ro8mx/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.

# %%
# !{sys.executable} -m pip install numpy --upgrade --ignore-installed
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# Collecting numpy
#   Using cached https://files.pythonhosted.org/packages/51/67/8907005262f493e356195bcbd61b41988eecf63cb1d97ea2f6e55fe24205/numpy-1.16.5-cp27-cp27m-macosx_10_9_x86_64.whl
# ERROR: cvxpy 1.0.25 has requirement scipy>=1.1.0, but you'll have scipy 1.0.0 which is incompatible.
# Installing collected packages: numpy
# Successfully installed numpy-1.16.5

# %% [markdown]
# ### Load Packages

# %%
import pandas as pd
import numpy as np
import helper
import project_helper
import project_tests
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-504bb0e8ad18> in <module>()
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import helper
#       4 import project_helper
#       5 import project_tests
#
# /opt/anaconda3/envs/AI4T/lib/python2.7/site-packages/pandas/__init__.py in <module>()
#      17 if missing_dependencies:
#      18     raise ImportError(
# ---> 19         "Missing required dependencies {0}".format(missing_dependencies))
#      20 del hard_dependencies, dependency, missing_dependencies
#      21
#
# ImportError: Missing required dependencies ['numpy']

# %% [markdown]
# ## Market Data
# ### Load Data
# For this universe of stocks, we'll be selecting large dollar volume stocks. We're using this universe, since it is highly liquid.

# %%
df = pd.read_csv('eod-quotemedia.csv')

percent_top_dollar = 0.2
high_volume_symbols = project_helper.large_dollar_volume_stocks(df, 'adj_close', 'adj_volume', percent_top_dollar)
df = df[df['ticker'].isin(high_volume_symbols)]

close = df.reset_index().pivot(index='date', columns='ticker', values='adj_close')
volume = df.reset_index().pivot(index='date', columns='ticker', values='adj_volume')
dividends = df.reset_index().pivot(index='date', columns='ticker', values='dividends')

# %% [markdown]
# ### View Data
# To see what one of these 2-d matrices looks like, let's take a look at the closing prices matrix.

# %%
project_helper.print_dataframe(close)

# %% [markdown]
# # Part 1: Smart Beta Portfolio
# In Part 1 of this project, you'll build a portfolio using dividend yield to choose the portfolio weights. A portfolio such as this could be incorporated into a smart beta ETF.  You'll compare this portfolio to a market cap weighted index to see how well it performs.
#
# Note that in practice, you'll probably get the index weights from a data vendor (such as companies that create indices, like MSCI, FTSE, Standard and Poor's), but for this exercise we will simulate a market cap weighted index.
#
# ## Index Weights
# The index we'll be using is based on large dollar volume stocks. Implement `generate_dollar_volume_weights` to generate the weights for this index. For each date, generate the weights based on dollar volume traded for that date. For example, assume the following is close prices and volume data:
# ```
#                  Prices
#                A         B         ...
# 2013-07-08     2         2         ...
# 2013-07-09     5         6         ...
# 2013-07-10     1         2         ...
# 2013-07-11     6         5         ...
# ...            ...       ...       ...
#
#                  Volume
#                A         B         ...
# 2013-07-08     100       340       ...
# 2013-07-09     240       220       ...
# 2013-07-10     120       500       ...
# 2013-07-11     10        100       ...
# ...            ...       ...       ...
# ```
# The weights created from the function `generate_dollar_volume_weights` should be the following:
# ```
#                A         B         ...
# 2013-07-08     0.126..   0.194..   ...
# 2013-07-09     0.759..   0.377..   ...
# 2013-07-10     0.075..   0.285..   ...
# 2013-07-11     0.037..   0.142..   ...
# ...            ...       ...       ...
# ```

# %%
def generate_dollar_volume_weights(close, volume):
    """
    Generate dollar volume weights.

    Parameters
    ----------
    close : DataFrame
        Close price for each ticker and date
    volume : str
        Volume for each ticker and date

    Returns
    -------
    dollar_volume_weights : DataFrame
        The dollar volume weights for each ticker and date
    """
    assert close.index.equals(volume.index)
    assert close.columns.equals(volume.columns)
    
    #TODO: Implement function
    dollar_volume = close * volume
    dollar_volume_weights = dollar_volume.divide(dollar_volume.sum(axis=1), axis=0)
    return dollar_volume_weights

project_tests.test_generate_dollar_volume_weights(generate_dollar_volume_weights)

# %% [markdown]
# ### View Data
# Let's generate the index weights using `generate_dollar_volume_weights` and view them using a heatmap.

# %%
index_weights = generate_dollar_volume_weights(close, volume)
project_helper.plot_weights(index_weights, 'Index Weights')

# %% [markdown]
# ## Portfolio Weights
# Now that we have the index weights, let's choose the portfolio weights based on dividend. You would normally calculate the weights based on trailing dividend yield, but we'll simplify this by just calculating the total dividend yield over time.
#
# Implement `calculate_dividend_weights` to return the weights for each stock based on its total dividend yield over time. This is similar to generating the weight for the index, but it's using dividend data instead.
# For example, assume the following is `dividends` data:
# ```
#                  Prices
#                A         B
# 2013-07-08     0         0
# 2013-07-09     0         1
# 2013-07-10     0.5       0
# 2013-07-11     0         0
# 2013-07-12     2         0
# ...            ...       ...
# ```
# The weights created from the function `calculate_dividend_weights` should be the following:
# ```
#                A         B
# 2013-07-08     NaN       NaN
# 2013-07-09     0         1
# 2013-07-10     0.333..   0.666..
# 2013-07-11     0.333..   0.666..
# 2013-07-12     0.714..   0.285..
# ...            ...       ...
# ```

# %%
def calculate_dividend_weights(dividends):
    """
    Calculate dividend weights.

    Parameters
    ----------
    ex_dividend : DataFrame
        Ex-dividend for each stock and date

    Returns
    -------
    dividend_weights : DataFrame
        Weights for each stock and date
    """
    #TODO: Implement function
    cum_dividend_yields = dividends.cumsum()
    dividend_weights = cum_dividend_yields.divide(cum_dividend_yields.sum(axis=1), axis=0)

    return dividend_weights

project_tests.test_calculate_dividend_weights(calculate_dividend_weights)

# %% [markdown]
# ### View Data
# Just like the index weights, let's generate the ETF weights and view them using a heatmap.

# %%
etf_weights = calculate_dividend_weights(dividends)
project_helper.plot_weights(etf_weights, 'ETF Weights')

# %% [markdown]
# ## Returns
# Implement `generate_returns` to generate returns data for all the stocks and dates from price data. You might notice we're implementing returns and not log returns. Since we're not dealing with volatility, we don't have to use log returns.

# %%
def generate_returns(prices):
    """
    Generate returns for ticker and date.

    Parameters
    ----------
    prices : DataFrame
        Price for each ticker and date

    Returns
    -------
    returns : Dataframe
        The returns for each ticker and date
    """
    #TODO: Implement function

    return (prices - prices.shift(1)) / prices.shift(1)

project_tests.test_generate_returns(generate_returns)

# %% [markdown]
# ### View Data
# Let's generate the closing returns using `generate_returns` and view them using a heatmap.

# %%
returns = generate_returns(close)
project_helper.plot_returns(returns, 'Close Returns')

# %% [markdown]
# ## Weighted Returns
# With the returns of each stock computed, we can use it to compute the returns for an index or ETF. Implement `generate_weighted_returns` to create weighted returns using the returns and weights.

# %%
def generate_weighted_returns(returns, weights):
    """
    Generate weighted returns.

    Parameters
    ----------
    returns : DataFrame
        Returns for each ticker and date
    weights : DataFrame
        Weights for each ticker and date

    Returns
    -------
    weighted_returns : DataFrame
        Weighted returns for each ticker and date
    """
    assert returns.index.equals(weights.index)
    assert returns.columns.equals(weights.columns)
    
    #TODO: Implement function

    return returns * weights

project_tests.test_generate_weighted_returns(generate_weighted_returns)

# %% [markdown]
# ### View Data
# Let's generate the ETF and index returns using `generate_weighted_returns` and view them using a heatmap.

# %%
index_weighted_returns = generate_weighted_returns(returns, index_weights)
etf_weighted_returns = generate_weighted_returns(returns, etf_weights)
project_helper.plot_returns(index_weighted_returns, 'Index Returns')
project_helper.plot_returns(etf_weighted_returns, 'ETF Returns')

# %% [markdown]
# ## Cumulative Returns
# To compare performance between the ETF and Index, we're going to calculate the tracking error. Before we do that, we first need to calculate the index and ETF comulative returns. Implement `calculate_cumulative_returns` to calculate the cumulative returns over time given the returns.

# %%
def calculate_cumulative_returns(returns):
    """
    Calculate cumulative returns.

    Parameters
    ----------
    returns : DataFrame
        Returns for each ticker and date

    Returns
    -------
    cumulative_returns : Pandas Series
        Cumulative returns for each date
    """
    #TODO: Implement function
    
    return (returns.sum(axis=1) + 1).cumprod()

project_tests.test_calculate_cumulative_returns(calculate_cumulative_returns)

# %% [markdown]
# ### View Data
# Let's generate the ETF and index cumulative returns using `calculate_cumulative_returns` and compare the two.

# %%
index_weighted_cumulative_returns = calculate_cumulative_returns(index_weighted_returns)
etf_weighted_cumulative_returns = calculate_cumulative_returns(etf_weighted_returns)
project_helper.plot_benchmark_returns(index_weighted_cumulative_returns, etf_weighted_cumulative_returns, 'Smart Beta ETF vs Index')

# %% [markdown]
# ## Tracking Error
# In order to check the performance of the smart beta portfolio, we can calculate the annualized tracking error against the index. Implement `tracking_error` to return the tracking error between the ETF and benchmark.
#
# For reference, we'll be using the following annualized tracking error function:
# $$ TE = \sqrt{252} * SampleStdev(r_p - r_b) $$
#
# Where $ r_p $ is the portfolio/ETF returns and $ r_b $ is the benchmark returns.
#
# _Note: When calculating the sample standard deviation, the delta degrees of freedom is 1, which is the also the default value._

# %%
def tracking_error(benchmark_returns_by_date, etf_returns_by_date):
    """
    Calculate the tracking error.

    Parameters
    ----------
    benchmark_returns_by_date : Pandas Series
        The benchmark returns for each date
    etf_returns_by_date : Pandas Series
        The ETF returns for each date

    Returns
    -------
    tracking_error : float
        The tracking error
    """
    assert benchmark_returns_by_date.index.equals(etf_returns_by_date.index)
    
    #TODO: Implement function

    return np.sqrt(252) * np.std(etf_returns_by_date - benchmark_returns_by_date, ddof=1)

project_tests.test_tracking_error(tracking_error)

# %% [markdown]
# ### View Data
# Let's generate the tracking error using `tracking_error`.

# %%
smart_beta_tracking_error = tracking_error(np.sum(index_weighted_returns, 1), np.sum(etf_weighted_returns, 1))
print('Smart Beta Tracking Error: {}'.format(smart_beta_tracking_error))

# %% [markdown]
# # Part 2: Portfolio Optimization
#
# Now, let's create a second portfolio.  We'll still reuse the market cap weighted index, but this will be independent of the dividend-weighted portfolio that we created in part 1.
#
# We want to both minimize the portfolio variance and also want to closely track a market cap weighted index.  In other words, we're trying to minimize the distance between the weights of our portfolio and the weights of the index.
#
# $Minimize \left [ \sigma^2_p + \lambda \sqrt{\sum_{1}^{m}(weight_i - indexWeight_i)^2} \right  ]$ where $m$ is the number of stocks in the portfolio, and $\lambda$ is a scaling factor that you can choose.
#
# Why are we doing this? One way that investors evaluate a fund is by how well it tracks its index. The fund is still expected to deviate from the index within a certain range in order to improve fund performance.  A way for a fund to track the performance of its benchmark is by keeping its asset weights similar to the weights of the index.  We’d expect that if the fund has the same stocks as the benchmark, and also the same weights for each stock as the benchmark, the fund would yield about the same returns as the benchmark. By minimizing a linear combination of both the portfolio risk and distance between portfolio and benchmark weights, we attempt to balance the desire to minimize portfolio variance with the goal of tracking the index.
#
#
# ## Covariance
# Implement `get_covariance_returns` to calculate the covariance of the `returns`. We'll use this to calculate the portfolio variance.
#
# If we have $m$ stock series, the covariance matrix is an $m \times m$ matrix containing the covariance between each pair of stocks.  We can use [`Numpy.cov`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.cov.html) to get the covariance.  We give it a 2D array in which each row is a stock series, and each column is an observation at the same period of time. For any `NaN` values, you can replace them with zeros using the [`DataFrame.fillna`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html) function.
#
# The covariance matrix $\mathbf{P} =
# \begin{bmatrix}
# \sigma^2_{1,1} & ... & \sigma^2_{1,m} \\
# ... & ... & ...\\
# \sigma_{m,1} & ... & \sigma^2_{m,m}  \\
# \end{bmatrix}$

# %%
def get_covariance_returns(returns):
    """
    Calculate covariance matrices.

    Parameters
    ----------
    returns : DataFrame
        Returns for each ticker and date

    Returns
    -------
    returns_covariance  : 2 dimensional Ndarray
        The covariance of the returns
    """
    #TODO: Implement function
    
    return np.cov(returns.T.fillna(0))

project_tests.test_get_covariance_returns(get_covariance_returns)

# %% [markdown]
# ### View Data
# Let's look at the covariance generated from `get_covariance_returns`.

# %%
covariance_returns = get_covariance_returns(returns)
covariance_returns = pd.DataFrame(covariance_returns, returns.columns, returns.columns)

covariance_returns_correlation = np.linalg.inv(np.diag(np.sqrt(np.diag(covariance_returns))))
covariance_returns_correlation = pd.DataFrame(
    covariance_returns_correlation.dot(covariance_returns).dot(covariance_returns_correlation),
    covariance_returns.index,
    covariance_returns.columns)

project_helper.plot_covariance_returns_correlation(
    covariance_returns_correlation,
    'Covariance Returns Correlation Matrix')

# %% [markdown]
# ### portfolio variance
# We can write the portfolio variance $\sigma^2_p = \mathbf{x^T} \mathbf{P} \mathbf{x}$
#
# Recall that the $\mathbf{x^T} \mathbf{P} \mathbf{x}$ is called the quadratic form.
# We can use the cvxpy function `quad_form(x,P)` to get the quadratic form.
#
# ### Distance from index weights
# We want portfolio weights that track the index closely.  So we want to minimize the distance between them.
# Recall from the Pythagorean theorem that you can get the distance between two points in an x,y plane by adding the square of the x and y distances and taking the square root.  Extending this to any number of dimensions is called the L2 norm.  So: $\sqrt{\sum_{1}^{n}(weight_i - indexWeight_i)^2}$  Can also be written as $\left \| \mathbf{x} - \mathbf{index} \right \|_2$.  There's a cvxpy function called [norm()](https://www.cvxpy.org/api_reference/cvxpy.atoms.other_atoms.html#norm)
# `norm(x, p=2, axis=None)`.  The default is already set to find an L2 norm, so you would pass in one argument, which is the difference between your portfolio weights and the index weights.
#
# ### objective function
# We want to minimize both the portfolio variance and the distance of the portfolio weights from the index weights.
# We also want to choose a `scale` constant, which is $\lambda$ in the expression.
#
# $\mathbf{x^T} \mathbf{P} \mathbf{x} + \lambda \left \| \mathbf{x} - \mathbf{index} \right \|_2$
#
#
# This lets us choose how much priority we give to minimizing the difference from the index, relative to minimizing the variance of the portfolio.  If you choose a higher value for `scale` ($\lambda$).
#
# We can find the objective function using cvxpy `objective = cvx.Minimize()`.  Can you guess what to pass into this function?

# %% [markdown]
# ### constraints
# We can also define our constraints in a list.  For example, you'd want the weights to sum to one. So $\sum_{1}^{n}x = 1$.  You may also need to go long only, which means no shorting, so no negative weights.  So $x_i >0 $ for all $i$. you could save a variable as `[x >= 0, sum(x) == 1]`, where x was created using `cvx.Variable()`.
#
# ### optimization
# So now that we have our objective function and constraints, we can solve for the values of $\mathbf{x}$.
# cvxpy has the constructor `Problem(objective, constraints)`, which returns a `Problem` object.
#
# The `Problem` object has a function solve(), which returns the minimum of the solution.  In this case, this is the minimum variance of the portfolio.
#
# It also updates the vector $\mathbf{x}$.
#
# We can check out the values of $x_A$ and $x_B$ that gave the minimum portfolio variance by using `x.value`

# %%
import cvxpy as cvx

def get_optimal_weights(covariance_returns, index_weights, scale=2.0):
    """
    Find the optimal weights.

    Parameters
    ----------
    covariance_returns : 2 dimensional Ndarray
        The covariance of the returns
    index_weights : Pandas Series
        Index weights for all tickers at a period in time
    scale : int
        The penalty factor for weights the deviate from the index 
    Returns
    -------
    x : 1 dimensional Ndarray
        The solution for x
    """
    assert len(covariance_returns.shape) == 2
    assert len(index_weights.shape) == 1
    assert covariance_returns.shape[0] == covariance_returns.shape[1]  == index_weights.shape[0]

    #TODO: Implement function
    
    # Number of index weights
    num_of_weights = len(index_weights)
    
    # x variables (to be found with optimization)
    x = cvx.Variable(num_of_weights)
    
    # Portfolio variance, in quadratic form
    portfolio_variance = cvx.quad_form(x, covariance_returns)
    
    # Distance (L2 norm) between portfolio and index weights
    distance_to_index = cvx.norm(x - index_weights, p=2)
    
    # Objective function
    objective = cvx.Minimize(portfolio_variance + scale * distance_to_index)
    
    # Constraints
    constraints = [x >= 0, sum(x) == 1]

    # Using cvxpy to solve the objective
    problem = cvx.Problem(objective, constraints)
    problem.solve()
    
    # Retrieve the weights of the optimized portfolio
    x_values = x.value
    
    return x_values

project_tests.test_get_optimal_weights(get_optimal_weights)

# %% [markdown]
# ## Optimized Portfolio
# Using the `get_optimal_weights` function, let's generate the optimal ETF weights without rebalanceing. We can do this by feeding in the covariance of the entire history of data. We also need to feed in a set of index weights. We'll go with the average weights of the index over time.

# %%
raw_optimal_single_rebalance_etf_weights = get_optimal_weights(covariance_returns.values, index_weights.iloc[-1])
optimal_single_rebalance_etf_weights = pd.DataFrame(
    np.tile(raw_optimal_single_rebalance_etf_weights, (len(returns.index), 1)),
    returns.index,
    returns.columns)

# %% [markdown]
# With our ETF weights built, let's compare it to the index. Run the next cell to calculate the ETF returns and compare it to the index returns.

# %%
optim_etf_returns = generate_weighted_returns(returns, optimal_single_rebalance_etf_weights)
optim_etf_cumulative_returns = calculate_cumulative_returns(optim_etf_returns)
project_helper.plot_benchmark_returns(index_weighted_cumulative_returns, optim_etf_cumulative_returns, 'Optimized ETF vs Index')

optim_etf_tracking_error = tracking_error(np.sum(index_weighted_returns, 1), np.sum(optim_etf_returns, 1))
print('Optimized ETF Tracking Error: {}'.format(optim_etf_tracking_error))

# %% [markdown]
# ## Rebalance Portfolio Over Time
# The single optimized ETF portfolio used the same weights for the entire history. This might not be the optimal weights for the entire period. Let's rebalance the portfolio over the same period instead of using the same weights. Implement `rebalance_portfolio` to rebalance a portfolio.
#
# Reblance the portfolio every n number of days, which is given as `shift_size`. When rebalancing, you should look back a certain number of days of data in the past, denoted as `chunk_size`. Using this data, compute the optimal weights using `get_optimal_weights` and `get_covariance_returns`.

# %%
def rebalance_portfolio(returns, index_weights, shift_size, chunk_size):
    """
    Get weights for each rebalancing of the portfolio.

    Parameters
    ----------
    returns : DataFrame
        Returns for each ticker and date
    index_weights : DataFrame
        Index weight for each ticker and date
    shift_size : int
        The number of days between each rebalance
    chunk_size : int
        The number of days to look in the past for rebalancing

    Returns
    -------
    all_rebalance_weights  : list of Ndarrays
        The ETF weights for each point they are rebalanced
    """
    assert returns.index.equals(index_weights.index)
    assert returns.columns.equals(index_weights.columns)
    assert shift_size > 0
    assert chunk_size >= 0
    
    #TODO: Implement function
    all_rebalance_weights = []

    for i in range(chunk_size, len(returns), shift_size):
        chunk = returns.iloc[i - chunk_size : i]
        covariance_returns = get_covariance_returns(chunk)
        optimal_weights = get_optimal_weights(covariance_returns, index_weights.iloc[i - 1])
        all_rebalance_weights.append(optimal_weights)
        
    return all_rebalance_weights

project_tests.test_rebalance_portfolio(rebalance_portfolio)

# %% [markdown]
# Run the following cell to rebalance the portfolio using `rebalance_portfolio`.

# %%
chunk_size = 250
shift_size = 5
all_rebalance_weights = rebalance_portfolio(returns, index_weights, shift_size, chunk_size)

# %% [markdown]
# ## Portfolio Turnover
# With the portfolio rebalanced, we need to use a metric to measure the cost of rebalancing the portfolio. Implement `get_portfolio_turnover` to calculate the annual portfolio turnover. We'll be using the formulas used in the classroom:
#
# $ AnnualizedTurnover =\frac{SumTotalTurnover}{NumberOfRebalanceEvents} * NumberofRebalanceEventsPerYear $
#
# $ SumTotalTurnover =\sum_{t,n}{\left | x_{t,n} - x_{t+1,n} \right |} $ Where $ x_{t,n} $ are the weights at time $ t $ for equity $ n $.
#
# $ SumTotalTurnover $ is just a different way of writing $ \sum \left | x_{t_1,n} - x_{t_2,n} \right | $

# %%
def get_portfolio_turnover(all_rebalance_weights, shift_size, rebalance_count, n_trading_days_in_year=252):
    """
    Calculage portfolio turnover.

    Parameters
    ----------
    all_rebalance_weights : list of Ndarrays
        The ETF weights for each point they are rebalanced
    shift_size : int
        The number of days between each rebalance
    rebalance_count : int
        Number of times the portfolio was rebalanced
    n_trading_days_in_year: int
        Number of trading days in a year

    Returns
    -------
    portfolio_turnover  : float
        The portfolio turnover
    """
    assert shift_size > 0
    assert rebalance_count > 0
    
    #TODO: Implement function
    sum_total_turnover = np.abs(np.diff(np.flip(all_rebalance_weights, axis=0), axis=0)).sum()
    number_rebalance_events_per_year = n_trading_days_in_year // shift_size
    annualized_turnover = (sum_total_turnover / rebalance_count) * number_rebalance_events_per_year
    
    return annualized_turnover

project_tests.test_get_portfolio_turnover(get_portfolio_turnover)

# %% [markdown]
# Run the following cell to get the portfolio turnover from  `get_portfolio turnover`.

# %%
print(get_portfolio_turnover(all_rebalance_weights, shift_size, len(all_rebalance_weights) - 1))

# %% [markdown]
# That's it! You've built a smart beta portfolio in part 1 and did portfolio optimization in part 2. You can now submit your project.

# %% [markdown]
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
